# %%
from influxdb import InfluxDBClient
client = InfluxDBClient(host='serviceproxy', port=8086)

# %%
client.get_list_database()
# Out:
# [{'name': '_internal'},
#  {'name': 'cdn'},
#  {'name': 'cdn_check_mk'},
#  {'name': 'locust'},
#  {'name': 'telegraf'}]

# %%
client.get_list_series(database='cdn_check_mk')
# Out:
# ['CPU_load,host=bln11-ds-01_arz_t-online_de,metrik=load1',
#  'CPU_load,host=bln11-ds-01_arz_t-online_de,metrik=load15',
#  'CPU_load,host=bln11-ds-01_arz_t-online_de,metrik=load5',
#  'CPU_load,host=bln11-ds-02_arz_t-online_de,metrik=load1',
#  'CPU_load,host=bln11-ds-02_arz_t-online_de,metrik=load15',
#  'CPU_load,host=bln11-ds-02_arz_t-online_de,metrik=load5',
#  'CPU_load,host=bln11-et-100_arz_t-online_de,metrik=load1',
#  'CPU_load,host=bln11-et-100_arz_t-online_de,metrik=load15',
#  'CPU_load,host=bln11-et-100_arz_t-online_de,metrik=load5',
#  'CPU_load,host=bln11-et-101_arz_t-online_de,metrik=load1',
#  'CPU_load,host=bln11-et-101_arz_t-online_de,metrik=load15',
#  'CPU_load,host=bln11-et-101_arz_t-online_de,metrik=load5',
#  'CPU_load,host=bln11-et-102_arz_t-online_de,metrik=load1',
#  'CPU_load,host=bln11-et-102_arz_t-online_de,metrik=load15',
#  'CPU_load,host=bln11-et-102_arz_t-online_de,metrik=load5',
#  'CPU_load,host=bln11-et-103_arz_t-online_de,metrik=load1',
# ...
